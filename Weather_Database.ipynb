# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 621

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city2 = ["houston","thomaston","New  York","Boston"]

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "houston"
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -95.36, 'lat': 29.76},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 75.6,
#   'feels_like': 81.32,
#   'temp_min': 73.4,
#   'temp_max': 77,
#   'pressure': 1015,
#   'humidity': 94},
#  'visibility': 14484,
#  'wind': {'speed': 6.93, 'deg': 130},
#  'rain': {'1h': 0.38},
#  'clouds': {'all': 75},
#  'dt': 1593106401,
#  'sys': {'type': 1,
#   'id': 4850,
#   'country': 'US',
#   'sunrise': 1593084156,
#   'sunset': 1593134739},
#  'timezone': -18000,
#  'id': 4699066,
#  'name': 'Houston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        city_rain = city_weather["rain"]["1h"]
        city_snow = city_weather["snow"]["1h"]

# If an error is experienced, skip the city.
    except KeyError as err:
        if err.args[0]=='coord':
            print(city + " not found. Skipping...")
            continue
        if err.args[0]=='rain':
            city_rain = 0
            if err.args[0]=='snow':
                city_snow = 0
        if err.args[0]=='snow':
            city_snow = 0
        
# Append the city information into city_data list.
    city_data.append({"City": city.title(),
                      "Country": city_country,
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Current Description": city_description,
                      "Rain (inches)": city_rain,
                      "Snow (inches)": city_snow})
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | tumannyy
# tumannyy not found. Skipping...
# Processing Record 3 of Set 1 | the valley
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | mantua
# Processing Record 6 of Set 1 | sucua
# Processing Record 7 of Set 1 | kaifeng
# Processing Record 8 of Set 1 | yuzhno-yeniseyskiy
# yuzhno-yeniseyskiy not found. Skipping...
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | bandundu
# Processing Record 14 of Set 1 | alta floresta
# Processing Record 15 of Set 1 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | kutum
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | northam
# Processing Record 20 of Set 1 | cabra
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | bayan
# Processing Record 25 of Set 1 | benjamin constant
# Processing Record 26 of Set 1 | puerto escondido
# Processing Record 27 of Set 1 | ostrovnoy
# Processing Record 28 of Set 1 | broken hill
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | kang
# Processing Record 31 of Set 1 | chantada
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | banda aceh
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | amderma
# amderma not found. Skipping...
# Processing Record 37 of Set 1 | beringovskiy
# Processing Record 38 of Set 1 | san cristobal
# Processing Record 39 of Set 1 | hovd
# Processing Record 40 of Set 1 | masjed-e soleyman
# masjed-e soleyman not found. Skipping...
# Processing Record 41 of Set 1 | pangoa
# Processing Record 42 of Set 1 | da lat
# Processing Record 43 of Set 1 | san ramon
# Processing Record 44 of Set 1 | sorland
# Processing Record 45 of Set 1 | khani
# Processing Record 46 of Set 1 | abadiania
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | kahului
# Processing Record 1 of Set 2 | pangnirtung
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | port hardy
# Processing Record 4 of Set 2 | komsomolskiy
# Processing Record 5 of Set 2 | tuatapere
# Processing Record 6 of Set 2 | luderitz
# Processing Record 7 of Set 2 | sao mateus do sul
# Processing Record 8 of Set 2 | kaitangata
# Processing Record 9 of Set 2 | berbera
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | berlevag
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 17 of Set 2 | zyryanka
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | mae hong son
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | otradnoye
# Processing Record 23 of Set 2 | isangel
# Processing Record 24 of Set 2 | xiuyan
# Processing Record 25 of Set 2 | kruisfontein
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | codrington
# Processing Record 28 of Set 2 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing Record 29 of Set 2 | belomorsk
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | acapulco
# Processing Record 32 of Set 2 | saint anthony
# Processing Record 33 of Set 2 | lompoc
# Processing Record 34 of Set 2 | kaa-khem
# Processing Record 35 of Set 2 | husavik
# Processing Record 36 of Set 2 | ampanihy
# Processing Record 37 of Set 2 | san francisco
# Processing Record 38 of Set 2 | sao filipe
# Processing Record 39 of Set 2 | akyab
# Processing Record 40 of Set 2 | carndonagh
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | kiruna
# Processing Record 43 of Set 2 | ribeira grande
# Processing Record 44 of Set 2 | cardonal
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | zanjan
# Processing Record 47 of Set 2 | port lincoln
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | toliary
# toliary not found. Skipping...
# Processing Record 50 of Set 2 | musoma
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | comodoro rivadavia
# Processing Record 3 of Set 3 | flinders
# Processing Record 4 of Set 3 | broome
# Processing Record 5 of Set 3 | esperance
# Processing Record 6 of Set 3 | seoul
# Processing Record 7 of Set 3 | terekli-mekteb
# Processing Record 8 of Set 3 | canico
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | ilulissat
# Processing Record 11 of Set 3 | merauke
# Processing Record 12 of Set 3 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 13 of Set 3 | khonuu
# khonuu not found. Skipping...
# Processing Record 14 of Set 3 | buala
# Processing Record 15 of Set 3 | cairns
# Processing Record 16 of Set 3 | mount isa
# Processing Record 17 of Set 3 | bolungarvik
# bolungarvik not found. Skipping...
# Processing Record 18 of Set 3 | visby
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | marawi
# Processing Record 21 of Set 3 | turayf
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | geraldton
# Processing Record 26 of Set 3 | aklavik
# Processing Record 27 of Set 3 | san rafael
# Processing Record 28 of Set 3 | vigrestad
# Processing Record 29 of Set 3 | pisco
# Processing Record 30 of Set 3 | kloulklubed
# Processing Record 31 of Set 3 | karratha
# Processing Record 32 of Set 3 | cherskiy
# Processing Record 33 of Set 3 | hihifo
# hihifo not found. Skipping...
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | tawkar
# tawkar not found. Skipping...
# Processing Record 36 of Set 3 | malakal
# Processing Record 37 of Set 3 | sur
# Processing Record 38 of Set 3 | susanville
# Processing Record 39 of Set 3 | marzuq
# Processing Record 40 of Set 3 | miri
# Processing Record 41 of Set 3 | karakendzha
# karakendzha not found. Skipping...
# Processing Record 42 of Set 3 | mul
# Processing Record 43 of Set 3 | san pedro de ycuamandiyu
# Processing Record 44 of Set 3 | clyde river
# Processing Record 45 of Set 3 | sampit
# Processing Record 46 of Set 3 | madarounfa
# Processing Record 47 of Set 3 | kudahuvadhoo
# Processing Record 48 of Set 3 | boqueirao
# Processing Record 49 of Set 3 | fortuna
# Processing Record 50 of Set 3 | lagoa
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | wilmington
# Processing Record 3 of Set 4 | masvingo
# Processing Record 4 of Set 4 | cidreira
# Processing Record 5 of Set 4 | naustdal
# Processing Record 6 of Set 4 | harper
# Processing Record 7 of Set 4 | arraial do cabo
# Processing Record 8 of Set 4 | praia da vitoria
# Processing Record 9 of Set 4 | provideniya
# Processing Record 10 of Set 4 | bambous virieux
# Processing Record 11 of Set 4 | albury
# Processing Record 12 of Set 4 | wajima
# Processing Record 13 of Set 4 | hobyo
# Processing Record 14 of Set 4 | kamenskoye
# kamenskoye not found. Skipping...
# Processing Record 15 of Set 4 | norman wells
# Processing Record 16 of Set 4 | raudeberg
# Processing Record 17 of Set 4 | boden
# Processing Record 18 of Set 4 | tual
# Processing Record 19 of Set 4 | tchibanga
# Processing Record 20 of Set 4 | rio gallegos
# Processing Record 21 of Set 4 | mar del plata
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | barcelos
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | creel
# Processing Record 26 of Set 4 | atka
# atka not found. Skipping...
# Processing Record 27 of Set 4 | boa vista
# Processing Record 28 of Set 4 | new norfolk
# Processing Record 29 of Set 4 | baie-saint-paul
# Processing Record 30 of Set 4 | kuche
# kuche not found. Skipping...
# Processing Record 31 of Set 4 | lorengau
# Processing Record 32 of Set 4 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 33 of Set 4 | chokurdakh
# Processing Record 34 of Set 4 | lokosovo
# Processing Record 35 of Set 4 | edson
# Processing Record 36 of Set 4 | kargasok
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | bud
# Processing Record 39 of Set 4 | woodward
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | werder
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | iquique
# Processing Record 44 of Set 4 | lavrentiya
# Processing Record 45 of Set 4 | rosita
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | shaunavon
# Processing Record 48 of Set 4 | ruhengeri
# Processing Record 49 of Set 4 | labutta
# labutta not found. Skipping...
# Processing Record 50 of Set 4 | pitalito
# Processing Record 1 of Set 5 | saint-gabriel
# Processing Record 2 of Set 5 | henties bay
# Processing Record 3 of Set 5 | faya
# Processing Record 4 of Set 5 | alofi
# Processing Record 5 of Set 5 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 6 of Set 5 | belmonte
# Processing Record 7 of Set 5 | vao
# Processing Record 8 of Set 5 | cabo san lucas
# Processing Record 9 of Set 5 | soyo
# Processing Record 10 of Set 5 | machado
# Processing Record 11 of Set 5 | auki
# Processing Record 12 of Set 5 | bang bo
# Processing Record 13 of Set 5 | kedrovyy
# Processing Record 14 of Set 5 | coahuayana
# Processing Record 15 of Set 5 | arlit
# Processing Record 16 of Set 5 | tasiilaq
# Processing Record 17 of Set 5 | jumla
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | hamada
# Processing Record 20 of Set 5 | san anselmo
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | dingle
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | anchorage
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | douentza
# Processing Record 27 of Set 5 | birjand
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 30 of Set 5 | thinadhoo
# Processing Record 31 of Set 5 | dikson
# Processing Record 32 of Set 5 | saint-gaudens
# Processing Record 33 of Set 5 | tura
# Processing Record 34 of Set 5 | kisangani
# Processing Record 35 of Set 5 | weihe
# Processing Record 36 of Set 5 | nhulunbuy
# Processing Record 37 of Set 5 | wenling
# Processing Record 38 of Set 5 | san carlos
# Processing Record 39 of Set 5 | naze
# Processing Record 40 of Set 5 | newport
# Processing Record 41 of Set 5 | los llanos de aridane
# Processing Record 42 of Set 5 | bathsheba
# Processing Record 43 of Set 5 | hidaka
# Processing Record 44 of Set 5 | ust-kamchatsk
# ust-kamchatsk not found. Skipping...
# Processing Record 45 of Set 5 | palabuhanratu
# palabuhanratu not found. Skipping...
# Processing Record 46 of Set 5 | shangrao
# Processing Record 47 of Set 5 | hambantota
# Processing Record 48 of Set 5 | manono
# Processing Record 49 of Set 5 | lieksa
# Processing Record 50 of Set 5 | yulara
# Processing Record 1 of Set 6 | monte carmelo
# Processing Record 2 of Set 6 | wasilla
# Processing Record 3 of Set 6 | aykhal
# Processing Record 4 of Set 6 | obihiro
# Processing Record 5 of Set 6 | tres arroyos
# Processing Record 6 of Set 6 | totness
# Processing Record 7 of Set 6 | matara
# Processing Record 8 of Set 6 | muisne
# Processing Record 9 of Set 6 | nuuk
# Processing Record 10 of Set 6 | khatanga
# Processing Record 11 of Set 6 | bay roberts
# Processing Record 12 of Set 6 | jinchengjiang
# jinchengjiang not found. Skipping...
# Processing Record 13 of Set 6 | ossora
# Processing Record 14 of Set 6 | vrsac
# Processing Record 15 of Set 6 | palma di montechiaro
# Processing Record 16 of Set 6 | sao joao da barra
# Processing Record 17 of Set 6 | araceli
# Processing Record 18 of Set 6 | asau
# Processing Record 19 of Set 6 | nouakchott
# Processing Record 20 of Set 6 | sao gabriel da cachoeira
# Processing Record 21 of Set 6 | jedrzejow
# Processing Record 22 of Set 6 | east london
# Processing Record 23 of Set 6 | grand gaube
# Processing Record 24 of Set 6 | nanortalik
# Processing Record 25 of Set 6 | aktash
# Processing Record 26 of Set 6 | mayor pablo lagerenza
# Processing Record 27 of Set 6 | bargal
# bargal not found. Skipping...
# Processing Record 28 of Set 6 | kyaikkami
# Processing Record 29 of Set 6 | rock sound
# Processing Record 30 of Set 6 | iralaya
# Processing Record 31 of Set 6 | meulaboh
# Processing Record 32 of Set 6 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 33 of Set 6 | derveni
# Processing Record 34 of Set 6 | hasaki
# Processing Record 35 of Set 6 | conceicao do mato dentro
# Processing Record 36 of Set 6 | bani walid
# Processing Record 37 of Set 6 | borzoy
# Processing Record 38 of Set 6 | dera din panah
# dera din panah not found. Skipping...
# Processing Record 39 of Set 6 | severo-yeniseyskiy
# Processing Record 40 of Set 6 | lhokseumawe
# Processing Record 41 of Set 6 | saint-francois
# Processing Record 42 of Set 6 | biak
# Processing Record 43 of Set 6 | port augusta
# Processing Record 44 of Set 6 | constitucion
# Processing Record 45 of Set 6 | kurilsk
# Processing Record 46 of Set 6 | saint george
# Processing Record 47 of Set 6 | riverton
# Processing Record 48 of Set 6 | butaritari
# Processing Record 49 of Set 6 | ketchikan
# Processing Record 50 of Set 6 | zaranj
# Processing Record 1 of Set 7 | kenai
# Processing Record 2 of Set 7 | roald
# Processing Record 3 of Set 7 | heihe
# Processing Record 4 of Set 7 | weihai
# Processing Record 5 of Set 7 | laguna
# Processing Record 6 of Set 7 | qaqortoq
# Processing Record 7 of Set 7 | huarmey
# Processing Record 8 of Set 7 | flin flon
# Processing Record 9 of Set 7 | victoria
# Processing Record 10 of Set 7 | tezu
# Processing Record 11 of Set 7 | pomabamba
# Processing Record 12 of Set 7 | dombarovskiy
# Processing Record 13 of Set 7 | kamariotissa
# Processing Record 14 of Set 7 | kalininsk
# Processing Record 15 of Set 7 | pak phanang
# Processing Record 16 of Set 7 | korla
# Processing Record 17 of Set 7 | williams lake
# Processing Record 18 of Set 7 | bara
# Processing Record 19 of Set 7 | eyl
# Processing Record 20 of Set 7 | ushtobe
# Processing Record 21 of Set 7 | lata
# Processing Record 22 of Set 7 | nantucket
# Processing Record 23 of Set 7 | sitka
# Processing Record 24 of Set 7 | waipawa
# Processing Record 25 of Set 7 | mamit
# Processing Record 26 of Set 7 | buckeye
# Processing Record 27 of Set 7 | iqaluit
# Processing Record 28 of Set 7 | taitung
# Processing Record 29 of Set 7 | ondangwa
# Processing Record 30 of Set 7 | tiksi
# Processing Record 31 of Set 7 | nachingwea
# Processing Record 32 of Set 7 | honiara
# Processing Record 33 of Set 7 | doctor arroyo
# Processing Record 34 of Set 7 | tomatlan
# Processing Record 35 of Set 7 | puerto ayacucho
# Processing Record 36 of Set 7 | upernavik
# Processing Record 37 of Set 7 | san jeronimo
# Processing Record 38 of Set 7 | lucea
# Processing Record 39 of Set 7 | hinton
# Processing Record 40 of Set 7 | sarangani
# Processing Record 41 of Set 7 | lolua
# lolua not found. Skipping...
# Processing Record 42 of Set 7 | getulio vargas
# Processing Record 43 of Set 7 | gamba
# Processing Record 44 of Set 7 | katsuura
# Processing Record 45 of Set 7 | chizhou
# Processing Record 46 of Set 7 | ponta delgada
# Processing Record 47 of Set 7 | imbituba
# Processing Record 48 of Set 7 | dicabisagan
# Processing Record 49 of Set 7 | topdac
# Processing Record 50 of Set 7 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 1 of Set 8 | cayenne
# Processing Record 2 of Set 8 | vila franca do campo
# Processing Record 3 of Set 8 | mount gambier
# Processing Record 4 of Set 8 | saleaula
# saleaula not found. Skipping...
# Processing Record 5 of Set 8 | nouadhibou
# Processing Record 6 of Set 8 | tucuma
# Processing Record 7 of Set 8 | kawana waters
# kawana waters not found. Skipping...
# Processing Record 8 of Set 8 | panzhihua
# Processing Record 9 of Set 8 | dapaong
# Processing Record 10 of Set 8 | pangody
# Processing Record 11 of Set 8 | enid
# Processing Record 12 of Set 8 | linjiang
# Processing Record 13 of Set 8 | pilar
# Processing Record 14 of Set 8 | abu samrah
# Processing Record 15 of Set 8 | egvekinot
# Processing Record 16 of Set 8 | stromness
# Processing Record 17 of Set 8 | contamana
# Processing Record 18 of Set 8 | palu
# Processing Record 19 of Set 8 | chimoio
# Processing Record 20 of Set 8 | baglung
# Processing Record 21 of Set 8 | letterkenny
# Processing Record 22 of Set 8 | buin
# Processing Record 23 of Set 8 | manoel urbano
# Processing Record 24 of Set 8 | vostochnyy
# Processing Record 25 of Set 8 | manhattan
# Processing Record 26 of Set 8 | shelburne
# Processing Record 27 of Set 8 | bentiu
# Processing Record 28 of Set 8 | hare bay
# Processing Record 29 of Set 8 | orcopampa
# Processing Record 30 of Set 8 | dolbeau
# dolbeau not found. Skipping...
# Processing Record 31 of Set 8 | yilan
# Processing Record 32 of Set 8 | sibolga
# Processing Record 33 of Set 8 | longfeng
# Processing Record 34 of Set 8 | srednekolymsk
# Processing Record 35 of Set 8 | bontang
# Processing Record 36 of Set 8 | camocim
# Processing Record 37 of Set 8 | sibu
# Processing Record 38 of Set 8 | pevek
# Processing Record 39 of Set 8 | montecchio maggiore
# Processing Record 40 of Set 8 | aguada de pasajeros
# Processing Record 41 of Set 8 | longyearbyen
# Processing Record 42 of Set 8 | luorong
# Processing Record 43 of Set 8 | nikki
# Processing Record 44 of Set 8 | tarasovskiy
# Processing Record 45 of Set 8 | porto novo
# Processing Record 46 of Set 8 | bria
# Processing Record 47 of Set 8 | hirara
# Processing Record 48 of Set 8 | wanning
# Processing Record 49 of Set 8 | jinchang
# Processing Record 50 of Set 8 | saint-leu
# Processing Record 1 of Set 9 | waingapu
# Processing Record 2 of Set 9 | halifax
# Processing Record 3 of Set 9 | taft
# Processing Record 4 of Set 9 | san angelo
# Processing Record 5 of Set 9 | santa cruz de la palma
# Processing Record 6 of Set 9 | changping
# Processing Record 7 of Set 9 | paramonga
# Processing Record 8 of Set 9 | aquiraz
# Processing Record 9 of Set 9 | zhanaozen
# Processing Record 10 of Set 9 | nova olinda do norte
# Processing Record 11 of Set 9 | praya
# Processing Record 12 of Set 9 | anadyr
# Processing Record 13 of Set 9 | santa isabel
# Processing Record 14 of Set 9 | meyungs
# meyungs not found. Skipping...
# Processing Record 15 of Set 9 | fougamou
# Processing Record 16 of Set 9 | basoko
# Processing Record 17 of Set 9 | maceio
# Processing Record 18 of Set 9 | marsh harbour
# Processing Record 19 of Set 9 | salalah
# Processing Record 20 of Set 9 | hereclean
# Processing Record 21 of Set 9 | sisimiut
# Processing Record 22 of Set 9 | peleduy
# Processing Record 23 of Set 9 | murray bridge
# Processing Record 24 of Set 9 | forestville
# Processing Record 25 of Set 9 | neuquen
# Processing Record 26 of Set 9 | impfondo
# Processing Record 27 of Set 9 | deputatskiy
# Processing Record 28 of Set 9 | coihaique
# Processing Record 29 of Set 9 | aflu
# aflu not found. Skipping...
# Processing Record 30 of Set 9 | kaputa
# Processing Record 31 of Set 9 | ust-nera
# Processing Record 32 of Set 9 | wankaner
# Processing Record 33 of Set 9 | high level
# Processing Record 34 of Set 9 | puerto narino
# Processing Record 35 of Set 9 | timbiqui
# Processing Record 36 of Set 9 | ocsa
# Processing Record 37 of Set 9 | haines junction
# Processing Record 38 of Set 9 | jalu
# Processing Record 39 of Set 9 | praia
# Processing Record 40 of Set 9 | dudinka
# Processing Record 41 of Set 9 | mongo
# Processing Record 42 of Set 9 | parker
# Processing Record 43 of Set 9 | broken arrow
# Processing Record 44 of Set 9 | tilichiki
# Processing Record 45 of Set 9 | burns lake
# Processing Record 46 of Set 9 | samarai
# Processing Record 47 of Set 9 | lusambo
# Processing Record 48 of Set 9 | saskylakh
# Processing Record 49 of Set 9 | spijkenisse
# Processing Record 50 of Set 9 | mumford
# Processing Record 1 of Set 10 | armilla
# Processing Record 2 of Set 10 | millinocket
# Processing Record 3 of Set 10 | chichimila
# Processing Record 4 of Set 10 | moju
# Processing Record 5 of Set 10 | dekar
# Processing Record 6 of Set 10 | rudbar
# Processing Record 7 of Set 10 | madawaska
# Processing Record 8 of Set 10 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 9 of Set 10 | westport
# Processing Record 10 of Set 10 | jishu
# Processing Record 11 of Set 10 | vestmannaeyjar
# Processing Record 12 of Set 10 | sinnamary
# Processing Record 13 of Set 10 | taoudenni
# Processing Record 14 of Set 10 | suez
# Processing Record 15 of Set 10 | ghansor
# Processing Record 16 of Set 10 | yuty
# Processing Record 17 of Set 10 | araouane
# Processing Record 18 of Set 10 | jian
# Processing Record 19 of Set 10 | krasnoselkup
# Processing Record 20 of Set 10 | canguaretama
# Processing Record 21 of Set 10 | linqiong
# Processing Record 22 of Set 10 | kankan
# Processing Record 23 of Set 10 | tatarsk
# Processing Record 24 of Set 10 | bonavista
# Processing Record 25 of Set 10 | cheuskiny
# cheuskiny not found. Skipping...
# Processing Record 26 of Set 10 | bestobe
# Processing Record 27 of Set 10 | vila velha
# Processing Record 28 of Set 10 | honningsvag
# Processing Record 29 of Set 10 | nguiu
# nguiu not found. Skipping...
# Processing Record 30 of Set 10 | halalo
# halalo not found. Skipping...
# Processing Record 31 of Set 10 | te anau
# Processing Record 32 of Set 10 | sao geraldo do araguaia
# Processing Record 33 of Set 10 | gustavo diaz ordaz
# Processing Record 34 of Set 10 | panguna
# Processing Record 35 of Set 10 | ijaki
# ijaki not found. Skipping...
# Processing Record 36 of Set 10 | ozernovskiy
# Processing Record 37 of Set 10 | kaeo
# Processing Record 38 of Set 10 | xining
# Processing Record 39 of Set 10 | kysyl-syr
# Processing Record 40 of Set 10 | nokaneng
# Processing Record 41 of Set 10 | tanout
# Processing Record 42 of Set 10 | nemuro
# Processing Record 43 of Set 10 | labuan
# Processing Record 44 of Set 10 | half moon bay
# Processing Record 45 of Set 10 | mana
# Processing Record 46 of Set 10 | terrace
# Processing Record 47 of Set 10 | bonthe
# Processing Record 48 of Set 10 | bairiki
# Processing Record 49 of Set 10 | touros
# Processing Record 50 of Set 10 | kamenka
# Processing Record 1 of Set 11 | pousat
# pousat not found. Skipping...
# Processing Record 2 of Set 11 | placido de castro
# Processing Record 3 of Set 11 | union
# Processing Record 4 of Set 11 | aguachica
# Processing Record 5 of Set 11 | imuris
# Processing Record 6 of Set 11 | omboue
# Processing Record 7 of Set 11 | avera
# Processing Record 8 of Set 11 | cayambe
# Processing Record 9 of Set 11 | phek
# Processing Record 10 of Set 11 | lazaro cardenas
# Processing Record 11 of Set 11 | vardo
# Processing Record 12 of Set 11 | dryden
# Processing Record 13 of Set 11 | dinghai
# Processing Record 14 of Set 11 | andra
# Processing Record 15 of Set 11 | hurghada
# Processing Record 16 of Set 11 | ahipara
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | leningradskiy
# Processing Record 19 of Set 11 | boatlaname
# boatlaname not found. Skipping...
# Processing Record 20 of Set 11 | zhigansk
# Processing Record 21 of Set 11 | gejiu
# Processing Record 22 of Set 11 | rocha
# Processing Record 23 of Set 11 | porbandar
# Processing Record 24 of Set 11 | yenagoa
# Processing Record 25 of Set 11 | luzhou
# Processing Record 26 of Set 11 | west bay
# Processing Record 27 of Set 11 | birin
# Processing Record 28 of Set 11 | mopti
# Processing Record 29 of Set 11 | verkhnyaya sinyachikha
# Processing Record 30 of Set 11 | kavieng
# Processing Record 31 of Set 11 | noumea
# Processing Record 32 of Set 11 | nome
# Processing Record 33 of Set 11 | savannah bight
# Processing Record 34 of Set 11 | santa cruz
# Processing Record 35 of Set 11 | oudtshoorn
# Processing Record 36 of Set 11 | taltal
# Processing Record 37 of Set 11 | lumphat
# Processing Record 38 of Set 11 | bowen
# Processing Record 39 of Set 11 | becsehely
# Processing Record 40 of Set 11 | mabaruma
# Processing Record 41 of Set 11 | burica
# burica not found. Skipping...
# Processing Record 42 of Set 11 | hit
# Processing Record 43 of Set 11 | porto uniao
# Processing Record 44 of Set 11 | yar-sale
# Processing Record 45 of Set 11 | ingham
# Processing Record 46 of Set 11 | general roca
# Processing Record 47 of Set 11 | ternate
# Processing Record 48 of Set 11 | porto velho
# Processing Record 49 of Set 11 | petropavlovskoye
# Processing Record 50 of Set 11 | ayios mamas
# Processing Record 1 of Set 12 | krasnotorka
# Processing Record 2 of Set 12 | cedar city
# Processing Record 3 of Set 12 | osypenko
# Processing Record 4 of Set 12 | ercis
# Processing Record 5 of Set 12 | mangrol
# Processing Record 6 of Set 12 | moreira sales
# Processing Record 7 of Set 12 | ambovombe
# Processing Record 8 of Set 12 | kieta
# Processing Record 9 of Set 12 | sidi bu zayd
# sidi bu zayd not found. Skipping...
# Processing Record 10 of Set 12 | rio grande
# Processing Record 11 of Set 12 | launceston
# Processing Record 12 of Set 12 | la gaulette
# la gaulette not found. Skipping...
# Processing Record 13 of Set 12 | garden city
# Processing Record 14 of Set 12 | bairnsdale
# Processing Record 15 of Set 12 | nagato
# Processing Record 16 of Set 12 | campo maior
# Processing Record 17 of Set 12 | lasa
# Processing Record 18 of Set 12 | bongandanga
# Processing Record 19 of Set 12 | leh
# Processing Record 20 of Set 12 | ancud
# Processing Record 21 of Set 12 | bandarbeyla
# Processing Record 22 of Set 12 | mbanza-ngungu
# Processing Record 23 of Set 12 | tambun
# Processing Record 24 of Set 12 | lingao
# Processing Record 25 of Set 12 | sola
# Processing Record 26 of Set 12 | sao borja
# Processing Record 27 of Set 12 | abu kamal
# Processing Record 28 of Set 12 | skibbereen
# Processing Record 29 of Set 12 | talnakh
# Processing Record 30 of Set 12 | daoukro
# Processing Record 31 of Set 12 | rungata
# rungata not found. Skipping...
# Processing Record 32 of Set 12 | toamasina
# Processing Record 33 of Set 12 | spencer
# Processing Record 34 of Set 12 | vire
# Processing Record 35 of Set 12 | walvis bay
# Processing Record 36 of Set 12 | santa fe
# Processing Record 37 of Set 12 | sinkat
# sinkat not found. Skipping...
# Processing Record 38 of Set 12 | turukhansk
# Processing Record 39 of Set 12 | poya
# Processing Record 40 of Set 12 | port-gentil
# Processing Record 41 of Set 12 | cienaga
# Processing Record 42 of Set 12 | marrakesh
# Processing Record 43 of Set 12 | north bend
# Processing Record 44 of Set 12 | kerrville
# Processing Record 45 of Set 12 | luau
# Processing Record 46 of Set 12 | seymchan
# Processing Record 47 of Set 12 | ankpa
# Processing Record 48 of Set 12 | louisbourg
# louisbourg not found. Skipping...
# Processing Record 49 of Set 12 | erdenet
# Processing Record 50 of Set 12 | sosva
# Processing Record 1 of Set 13 | mogadishu
# Processing Record 2 of Set 13 | kazalinsk
# kazalinsk not found. Skipping...
# Processing Record 3 of Set 13 | daru
# Processing Record 4 of Set 13 | kisujszallas
# Processing Record 5 of Set 13 | nchelenge
# Processing Record 6 of Set 13 | pyay
# Processing Record 7 of Set 13 | missoula
# Processing Record 8 of Set 13 | bababe
# bababe not found. Skipping...
# Processing Record 9 of Set 13 | san jose
# Processing Record 10 of Set 13 | champerico
# Processing Record 11 of Set 13 | saint-louis
# Processing Record 12 of Set 13 | salekhard
# Processing Record 13 of Set 13 | argelia
# Processing Record 14 of Set 13 | taunggyi
# Processing Record 15 of Set 13 | pagudpud
# Processing Record 16 of Set 13 | mayumba
# Processing Record 17 of Set 13 | coxim
# Processing Record 18 of Set 13 | san joaquin
# Processing Record 19 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 13 | maun
# Processing Record 21 of Set 13 | nsanje
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 571

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Yellowknife      CA  62.46 -114.35     60.80        63          75
# 1   The Valley      AI  18.22  -63.06     87.80        58          40
# 2       Hobart      AU -42.88  147.33     46.40        70          40
# 3       Mantua      IT  45.17   10.78     78.01        63           5
# 4        Sucua      EC  -2.47  -78.17     66.20        93          90
# 5      Kaifeng      CN  34.79  114.35     82.40        69          20
# 6       Bethel      US  41.37  -73.41     84.00        34           1
# 7       Barrow      US  71.29 -156.79     35.60        93          90
# 8       Avarua      CK -21.21 -159.78     68.00        82          30
# 9     Hermanus      ZA -34.42   19.23     59.00        85          17
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0       11.41       broken clouds           0.00              0
# 1       18.34    scattered clouds           0.00              0
# 2       12.75    scattered clouds           0.00              0
# 3       10.00           clear sky           0.00              0
# 4        5.82          light rain           0.00              0
# 5        6.71          few clouds           0.00              0
# 6       11.41           clear sky           0.00              0
# 7       16.11                 fog           0.00              0
# 8        3.36    scattered clouds           0.00              0
# 9        3.00       moderate rain           1.03              0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
